# %% [markdown]
# # Stock NeurIPS2018 Part 2. Train
# This series is a reproduction of *the process in the paper Practical Deep Reinforcement Learning Approach for Stock Trading*.
#
# This is the second part of the NeurIPS2018 series, introducing how to use FinRL to make data into the gym form environment, and train DRL agents on it.
#
# Other demos can be found at the repo of [FinRL-Tutorials]((https://github.com/AI4Finance-Foundation/FinRL-Tutorials)).

# %% [markdown]
# # Part 1. Install Packages

# %%
## install required packages
# !pip install swig
# !pip install wrds
# !pip install pyportfolioopt
## install finrl library
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: swig in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (4.2.1)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: wrds in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (3.2.0)
# Requirement already satisfied: scipy<1.13,>=1.12 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from wrds) (1.12.0)
# Requirement already satisfied: numpy<1.27,>=1.26 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from wrds) (1.26.4)
# Requirement already satisfied: pandas<2.3,>=2.2 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from wrds) (2.2.1)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from wrds) (2.9.9)
# Requirement already satisfied: packaging<23.3 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from wrds) (23.2)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from wrds) (2.0.29)
# Requirement already satisfied: tzdata>=2022.7 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from pandas<2.3,>=2.2->wrds) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from pandas<2.3,>=2.2->wrds) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from pandas<2.3,>=2.2->wrds) (2024.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from sqlalchemy<2.1,>=2->wrds) (4.10.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from sqlalchemy<2.1,>=2->wrds) (3.0.3)
# Requirement already satisfied: six>=1.5 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2->wrds) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pyportfolioopt in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (1.5.5)
# Requirement already satisfied: pandas>=0.19 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from pyportfolioopt) (2.2.1)
# Requirement already satisfied: scipy<2.0,>=1.3 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from pyportfolioopt) (1.12.0)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from pyportfolioopt) (1.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from pyportfolioopt) (1.26.4)
# Requirement already satisfied: scs>=3.0 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (3.2.4.post1)
# Requirement already satisfied: pybind11 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (2.12.0)
# Requirement already satisfied: ecos>=2 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (2.0.13)
# Requirement already satisfied: clarabel>=0.5.0 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (0.7.1)
# Requirement already satisfied: osqp>=0.6.2 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (0.6.4)
# Requirement already satisfied: tzdata>=2022.7 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from pandas>=0.19->pyportfolioopt) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from pandas>=0.19->pyportfolioopt) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from pandas>=0.19->pyportfolioopt) (2.9.0.post0)
# Requirement already satisfied: qdldl in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->pyportfolioopt) (0.1.7.post0)
# Requirement already satisfied: six>=1.5 in /home/kali/.pyenv/versions/3.10.14/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pyportfolioopt) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-d5u1hwqu
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-d5u1hwqu
# ^C
# ERROR: Operation cancelled by user
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import pandas as pd

from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3.common.logger import configure
from finrl import config_tickers
from finrl.main import check_and_make_directories
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR

check_and_make_directories([TRAINED_MODEL_DIR])

# %% [markdown]
# # Part 2. Build A Market Environment in OpenAI Gym-style

# %% [markdown]
# ![rl_diagram_transparent_bg.png](data:image/png;base64,...)

# %% [markdown]
# The core element in reinforcement learning are **agent** and **environment**. You can understand RL as the following process:
#
# The agent is active in a world, which is the environment. It observe its current condition as a **state**, and is allowed to do certain **actions**. After the agent execute an action, it will arrive at a new state. At the same time, the environment will have feedback to the agent called **reward**, a numerical signal that tells how good or bad the new state is. As the figure above, agent and environment will keep doing this interaction.
#
# The goal of agent is to get as much cumulative reward as possible. Reinforcement learning is the method that agent learns to improve its behavior and achieve that goal.

# %% [markdown]
# To achieve this in Python, we follow the OpenAI gym style to build the stock data into environment.
#
# state-action-reward are specified as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes the price data and technical indicators based on the past data. It will learn by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 constituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.

# %% [markdown]
# ## Read data
#
# We first read the .csv file of our training data into dataframe.

# %%
train = pd.read_csv('../data/trade_data1.csv')

# If you are not using the data generated from part 1 of this tutorial, make sure 
# it has the columns and index in the form that could be make into the environment. 
# Then you can comment and skip the following two lines.
train = train.set_index(train.columns[0])
train.index.names = ['']

# %% [markdown]
# ## Construct the environment

# %% [markdown]
# Calculate and specify the parameters we need for constructing the environment.

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# # Part 3: Train DRL Agents
# * Here, the DRL algorithms are from **[Stable Baselines 3](https://stable-baselines3.readthedocs.io/en/master/)**. It's a library that implemented popular DRL algorithms using pytorch, succeeding to its old version: Stable Baselines.
# * Users are also encouraged to try **[ElegantRL](https://github.com/AI4Finance-Foundation/ElegantRL)** and **[Ray RLlib](https://github.com/ray-project/ray)**.

# %%
agent = DRLAgent(env = env_train)

# Set the corresponding values to 'True' for the algorithms that you want to use
if_using_a2c = True
if_using_ddpg = False
if_using_ppo = False
if_using_td3 = False
if_using_sac = False

# %% [markdown]
# ## Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# ---------------------------------------
# | time/                 |             |
# |    fps                | 396         |
# |    iterations         | 100         |
# |    time_elapsed       | 1           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -1.38e-05   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -29.4       |
# |    reward             | -0.21007279 |
# |    std                | 1           |
# |    value_loss         | 0.613       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 385         |
# |    iterations         | 200         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0.364       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | 6.94        |
# |    reward             | 0.026236836 |
# |    std                | 1.01        |
# |    value_loss         | 0.25        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 394         |
# |    iterations         | 300         |
# |    time_elapsed       | 3           |
# |    total_timesteps    | 1500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | -0.00143    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 299         |
# |    policy_loss        | -5.13       |
# |    reward             | -0.03899439 |
# |    std                | 1.01        |
# |    value_loss         | 0.22        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 400       |
# |    iterations         | 400       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0.341     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 39.5      |
# |    reward             | 1.5560186 |
# |    std                | 1.01      |
# |    value_loss         | 1.04      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 404         |
# |    iterations         | 500         |
# |    time_elapsed       | 6           |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | -0.169      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | 59.5        |
# |    reward             | -0.32672426 |
# |    std                | 1.01        |
# |    value_loss         | 3.06        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 600      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | -0.191   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -49.8    |
# |    reward             | 0.500232 |
# |    std                | 1.01     |
# |    value_loss         | 1.87     |
# ------------------------------------
# day: 334, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1140528.52
# total_reward: 140528.52
# total_cost: 40871.99
# total_trades: 6994
# Sharpe: 0.757
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 407       |
# |    iterations         | 700       |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.0361   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -38.4     |
# |    reward             | 1.1121178 |
# |    std                | 1.01      |
# |    value_loss         | 1.27      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 408       |
# |    iterations         | 800       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.083    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 17        |
# |    reward             | -1.089963 |
# |    std                | 1.01      |
# |    value_loss         | 3.43      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 408       |
# |    iterations         | 900       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.191    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 36.7      |
# |    reward             | 2.1487844 |
# |    std                | 1.01      |
# |    value_loss         | 1.58      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 409       |
# |    iterations         | 1000      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 45.8      |
# |    reward             | 0.5066047 |
# |    std                | 1.01      |
# |    value_loss         | 1.36      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 411         |
# |    iterations         | 1100        |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | -10         |
# |    reward             | -0.25643095 |
# |    std                | 1.01        |
# |    value_loss         | 1.08        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 413        |
# |    iterations         | 1200       |
# |    time_elapsed       | 14         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -62.7      |
# |    reward             | 0.09920769 |
# |    std                | 1.01       |
# |    value_loss         | 2.42       |
# --------------------------------------
# day: 334, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 1375788.70
# total_reward: 375788.70
# total_cost: 11087.53
# total_trades: 6033
# Sharpe: 1.444
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 413        |
# |    iterations         | 1300       |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -0.076     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -101       |
# |    reward             | 0.03270517 |
# |    std                | 1.01       |
# |    value_loss         | 6.53       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 414        |
# |    iterations         | 1400       |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0.0749     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | -30        |
# |    reward             | -1.0509391 |
# |    std                | 1.01       |
# |    value_loss         | 0.783      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 414         |
# |    iterations         | 1500        |
# |    time_elapsed       | 18          |
# |    total_timesteps    | 7500        |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1499        |
# |    policy_loss        | 91.2        |
# |    reward             | -0.26146933 |
# |    std                | 1.01        |
# |    value_loss         | 6.72        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 414       |
# |    iterations         | 1600      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | 4.49      |
# |    reward             | 0.7305694 |
# |    std                | 1.01      |
# |    value_loss         | 0.693     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 412         |
# |    iterations         | 1700        |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 8500        |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1699        |
# |    policy_loss        | 19.6        |
# |    reward             | -0.13267596 |
# |    std                | 1.01        |
# |    value_loss         | 1.13        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 413        |
# |    iterations         | 1800       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -44.4      |
# |    reward             | -0.7990019 |
# |    std                | 1.01       |
# |    value_loss         | 1.69       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 410         |
# |    iterations         | 1900        |
# |    time_elapsed       | 23          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -41.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | -52.3       |
# |    reward             | -0.44969186 |
# |    std                | 1.02        |
# |    value_loss         | 2.37        |
# ---------------------------------------
# day: 334, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1324996.89
# total_reward: 324996.89
# total_cost: 7268.54
# total_trades: 5807
# Sharpe: 1.344
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 408        |
# |    iterations         | 2000       |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -97.9      |
# |    reward             | -0.7303273 |
# |    std                | 1.02       |
# |    value_loss         | 6.63       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 408        |
# |    iterations         | 2100       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 10500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | 12.8       |
# |    reward             | -0.4839967 |
# |    std                | 1.02       |
# |    value_loss         | 1.21       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 409        |
# |    iterations         | 2200       |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | -96.1      |
# |    reward             | -0.9435205 |
# |    std                | 1.02       |
# |    value_loss         | 7.69       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 409       |
# |    iterations         | 2300      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -29       |
# |    reward             | 0.0456024 |
# |    std                | 1.02      |
# |    value_loss         | 1.49      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 408        |
# |    iterations         | 2400       |
# |    time_elapsed       | 29         |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | -15.5      |
# |    reward             | 0.08487331 |
# |    std                | 1.02       |
# |    value_loss         | 1.4        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 408        |
# |    iterations         | 2500       |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 12500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -0.7       |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | -16.6      |
# |    reward             | -0.3330048 |
# |    std                | 1.02       |
# |    value_loss         | 1.26       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 408        |
# |    iterations         | 2600       |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 13000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2599       |
# |    policy_loss        | 3.2        |
# |    reward             | -0.2189926 |
# |    std                | 1.02       |
# |    value_loss         | 0.664      |
# --------------------------------------
# day: 334, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1338037.43
# total_reward: 338037.43
# total_cost: 8935.08
# total_trades: 6009
# Sharpe: 1.375
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 408        |
# |    iterations         | 2700       |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | 10.1       |
# |    reward             | -1.6705811 |
# |    std                | 1.02       |
# |    value_loss         | 2.92       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 408       |
# |    iterations         | 2800      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | -1.83     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -32.2     |
# |    reward             | 0.8329664 |
# |    std                | 1.02      |
# |    value_loss         | 2.2       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 409       |
# |    iterations         | 2900      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | 228       |
# |    reward             | 0.9017811 |
# |    std                | 1.02      |
# |    value_loss         | 44.7      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 409          |
# |    iterations         | 3000         |
# |    time_elapsed       | 36           |
# |    total_timesteps    | 15000        |
# | train/                |              |
# |    entropy_loss       | -41.8        |
# |    explained_variance | 1.19e-07     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2999         |
# |    policy_loss        | 35.8         |
# |    reward             | -0.042788588 |
# |    std                | 1.02         |
# |    value_loss         | 1.65         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 409        |
# |    iterations         | 3100       |
# |    time_elapsed       | 37         |
# |    total_timesteps    | 15500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0.325      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3099       |
# |    policy_loss        | -153       |
# |    reward             | -0.1756702 |
# |    std                | 1.02       |
# |    value_loss         | 17.5       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 409         |
# |    iterations         | 3200        |
# |    time_elapsed       | 39          |
# |    total_timesteps    | 16000       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | -0.502      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3199        |
# |    policy_loss        | 76.2        |
# |    reward             | 0.029711029 |
# |    std                | 1.03        |
# |    value_loss         | 5.33        |
# ---------------------------------------
# day: 334, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 1346986.91
# total_reward: 346986.91
# total_cost: 7466.94
# total_trades: 5552
# Sharpe: 1.443
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 409       |
# |    iterations         | 3300      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -3.32     |
# |    reward             | -0.867682 |
# |    std                | 1.03      |
# |    value_loss         | 0.455     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 409         |
# |    iterations         | 3400        |
# |    time_elapsed       | 41          |
# |    total_timesteps    | 17000       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | 0.304       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3399        |
# |    policy_loss        | -71.8       |
# |    reward             | -0.45519873 |
# |    std                | 1.03        |
# |    value_loss         | 5.92        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 409         |
# |    iterations         | 3500        |
# |    time_elapsed       | 42          |
# |    total_timesteps    | 17500       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3499        |
# |    policy_loss        | 32          |
# |    reward             | -0.65905124 |
# |    std                | 1.03        |
# |    value_loss         | 1.11        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 408         |
# |    iterations         | 3600        |
# |    time_elapsed       | 44          |
# |    total_timesteps    | 18000       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3599        |
# |    policy_loss        | -71.9       |
# |    reward             | -0.18810575 |
# |    std                | 1.03        |
# |    value_loss         | 3.82        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 3700      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 4.95e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 113       |
# |    reward             | 0.9481138 |
# |    std                | 1.03      |
# |    value_loss         | 9.82      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 405        |
# |    iterations         | 3800       |
# |    time_elapsed       | 46         |
# |    total_timesteps    | 19000      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | -5.51e-05  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3799       |
# |    policy_loss        | -19.8      |
# |    reward             | -0.1757353 |
# |    std                | 1.03       |
# |    value_loss         | 0.351      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 405        |
# |    iterations         | 3900       |
# |    time_elapsed       | 48         |
# |    total_timesteps    | 19500      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0.461      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3899       |
# |    policy_loss        | -5.17      |
# |    reward             | 0.86959755 |
# |    std                | 1.03       |
# |    value_loss         | 0.0933     |
# --------------------------------------
# day: 334, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 1200352.73
# total_reward: 200352.73
# total_cost: 11085.55
# total_trades: 5465
# Sharpe: 0.985
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 403         |
# |    iterations         | 4000        |
# |    time_elapsed       | 49          |
# |    total_timesteps    | 20000       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3999        |
# |    policy_loss        | 82.8        |
# |    reward             | -0.27286342 |
# |    std                | 1.03        |
# |    value_loss         | 4.32        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 404         |
# |    iterations         | 4100        |
# |    time_elapsed       | 50          |
# |    total_timesteps    | 20500       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0.0241      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4099        |
# |    policy_loss        | 15.1        |
# |    reward             | -0.96010494 |
# |    std                | 1.03        |
# |    value_loss         | 2.7         |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 405         |
# |    iterations         | 4200        |
# |    time_elapsed       | 51          |
# |    total_timesteps    | 21000       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4199        |
# |    policy_loss        | 72.4        |
# |    reward             | -0.08193702 |
# |    std                | 1.03        |
# |    value_loss         | 2.69        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 4300      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -36.2     |
# |    reward             | 1.4859718 |
# |    std                | 1.03      |
# |    value_loss         | 1.22      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 4400      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -0.974    |
# |    reward             | 1.8277686 |
# |    std                | 1.03      |
# |    value_loss         | 2.31      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 406        |
# |    iterations         | 4500       |
# |    time_elapsed       | 55         |
# |    total_timesteps    | 22500      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4499       |
# |    policy_loss        | -6.29      |
# |    reward             | -1.1008278 |
# |    std                | 1.03       |
# |    value_loss         | 1.14       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 406         |
# |    iterations         | 4600        |
# |    time_elapsed       | 56          |
# |    total_timesteps    | 23000       |
# | train/                |             |
# |    entropy_loss       | -42.1       |
# |    explained_variance | 0.0445      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4599        |
# |    policy_loss        | 89.8        |
# |    reward             | -0.08849541 |
# |    std                | 1.03        |
# |    value_loss         | 6.45        |
# ---------------------------------------
# day: 334, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1385541.57
# total_reward: 385541.57
# total_cost: 14041.05
# total_trades: 5986
# Sharpe: 1.682
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 406        |
# |    iterations         | 4700       |
# |    time_elapsed       | 57         |
# |    total_timesteps    | 23500      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4699       |
# |    policy_loss        | -105       |
# |    reward             | 0.38131952 |
# |    std                | 1.03       |
# |    value_loss         | 7.21       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 406        |
# |    iterations         | 4800       |
# |    time_elapsed       | 59         |
# |    total_timesteps    | 24000      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4799       |
# |    policy_loss        | -65        |
# |    reward             | 0.66549504 |
# |    std                | 1.04       |
# |    value_loss         | 2.9        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 407       |
# |    iterations         | 4900      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 0.00575   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | 249       |
# |    reward             | -3.443972 |
# |    std                | 1.04      |
# |    value_loss         | 39.6      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 407          |
# |    iterations         | 5000         |
# |    time_elapsed       | 61           |
# |    total_timesteps    | 25000        |
# | train/                |              |
# |    entropy_loss       | -42.2        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4999         |
# |    policy_loss        | -40.9        |
# |    reward             | -0.085510485 |
# |    std                | 1.04         |
# |    value_loss         | 1.15         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 407       |
# |    iterations         | 5100      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -42.2     |
# |    explained_variance | 0.0792    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 9.19      |
# |    reward             | 0.7533833 |
# |    std                | 1.04      |
# |    value_loss         | 0.0818    |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 408        |
# |    iterations         | 5200       |
# |    time_elapsed       | 63         |
# |    total_timesteps    | 26000      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5199       |
# |    policy_loss        | 10.8       |
# |    reward             | -0.7320826 |
# |    std                | 1.04       |
# |    value_loss         | 0.35       |
# --------------------------------------
# day: 334, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1307299.92
# total_reward: 307299.92
# total_cost: 5990.75
# total_trades: 5807
# Sharpe: 1.416
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 408         |
# |    iterations         | 5300        |
# |    time_elapsed       | 64          |
# |    total_timesteps    | 26500       |
# | train/                |             |
# |    entropy_loss       | -42.3       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5299        |
# |    policy_loss        | 19.5        |
# |    reward             | -0.23326631 |
# |    std                | 1.04        |
# |    value_loss         | 0.582       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 409        |
# |    iterations         | 5400       |
# |    time_elapsed       | 65         |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | 57.2       |
# |    reward             | -0.5082577 |
# |    std                | 1.04       |
# |    value_loss         | 2.23       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 409         |
# |    iterations         | 5500        |
# |    time_elapsed       | 67          |
# |    total_timesteps    | 27500       |
# | train/                |             |
# |    entropy_loss       | -42.3       |
# |    explained_variance | -0.64       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5499        |
# |    policy_loss        | 69.5        |
# |    reward             | -0.58904666 |
# |    std                | 1.04        |
# |    value_loss         | 3.33        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 409        |
# |    iterations         | 5600       |
# |    time_elapsed       | 68         |
# |    total_timesteps    | 28000      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5599       |
# |    policy_loss        | 59.3       |
# |    reward             | 0.18361908 |
# |    std                | 1.04       |
# |    value_loss         | 1.91       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 410      |
# |    iterations         | 5700     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -42.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -66.6    |
# |    reward             | 0.617152 |
# |    std                | 1.04     |
# |    value_loss         | 2.92     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 410       |
# |    iterations         | 5800      |
# |    time_elapsed       | 70        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | 97.8      |
# |    reward             | 2.0505373 |
# |    std                | 1.05      |
# |    value_loss         | 5.19      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 410        |
# |    iterations         | 5900       |
# |    time_elapsed       | 71         |
# |    total_timesteps    | 29500      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5899       |
# |    policy_loss        | -30.4      |
# |    reward             | -1.4347718 |
# |    std                | 1.05       |
# |    value_loss         | 0.672      |
# --------------------------------------
# day: 334, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 1317385.83
# total_reward: 317385.83
# total_cost: 6162.23
# total_trades: 5989
# Sharpe: 1.478
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 410       |
# |    iterations         | 6000      |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | -58.7     |
# |    reward             | 1.4104044 |
# |    std                | 1.05      |
# |    value_loss         | 2.35      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 411        |
# |    iterations         | 6100       |
# |    time_elapsed       | 74         |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -42.5      |
# |    explained_variance | -17.8      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | 151        |
# |    reward             | -1.3719333 |
# |    std                | 1.05       |
# |    value_loss         | 21.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 411        |
# |    iterations         | 6200       |
# |    time_elapsed       | 75         |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | 169        |
# |    reward             | -1.5413167 |
# |    std                | 1.05       |
# |    value_loss         | 16         |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 411         |
# |    iterations         | 6300        |
# |    time_elapsed       | 76          |
# |    total_timesteps    | 31500       |
# | train/                |             |
# |    entropy_loss       | -42.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6299        |
# |    policy_loss        | -43         |
# |    reward             | -0.46190125 |
# |    std                | 1.05        |
# |    value_loss         | 1.18        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 411       |
# |    iterations         | 6400      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -42.7     |
# |    explained_variance | 0.278     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 53.2      |
# |    reward             | 3.8310993 |
# |    std                | 1.05      |
# |    value_loss         | 2.86      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 412        |
# |    iterations         | 6500       |
# |    time_elapsed       | 78         |
# |    total_timesteps    | 32500      |
# | train/                |            |
# |    entropy_loss       | -42.7      |
# |    explained_variance | 0.101      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | -489       |
# |    reward             | -0.7965067 |
# |    std                | 1.06       |
# |    value_loss         | 158        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 412      |
# |    iterations         | 6600     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -42.8    |
# |    explained_variance | 0.000104 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -111     |
# |    reward             | 1.806222 |
# |    std                | 1.06     |
# |    value_loss         | 7.4      |
# ------------------------------------
# day: 334, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 1318753.10
# total_reward: 318753.10
# total_cost: 6531.86
# total_trades: 5673
# Sharpe: 1.431
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 412        |
# |    iterations         | 6700       |
# |    time_elapsed       | 81         |
# |    total_timesteps    | 33500      |
# | train/                |            |
# |    entropy_loss       | -42.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6699       |
# |    policy_loss        | 63.3       |
# |    reward             | -1.9115205 |
# |    std                | 1.06       |
# |    value_loss         | 3.41       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 412        |
# |    iterations         | 6800       |
# |    time_elapsed       | 82         |
# |    total_timesteps    | 34000      |
# | train/                |            |
# |    entropy_loss       | -42.8      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6799       |
# |    policy_loss        | 78.7       |
# |    reward             | -2.8302457 |
# |    std                | 1.06       |
# |    value_loss         | 4.03       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 413         |
# |    iterations         | 6900        |
# |    time_elapsed       | 83          |
# |    total_timesteps    | 34500       |
# | train/                |             |
# |    entropy_loss       | -42.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6899        |
# |    policy_loss        | -33.5       |
# |    reward             | -0.18450397 |
# |    std                | 1.06        |
# |    value_loss         | 2.66        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 413      |
# |    iterations         | 7000     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -42.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.718   |
# |    reward             | 1.646044 |
# |    std                | 1.06     |
# |    value_loss         | 0.267    |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 413         |
# |    iterations         | 7100        |
# |    time_elapsed       | 85          |
# |    total_timesteps    | 35500       |
# | train/                |             |
# |    entropy_loss       | -42.7       |
# |    explained_variance | 0.273       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7099        |
# |    policy_loss        | 83.7        |
# |    reward             | -0.11341326 |
# |    std                | 1.06        |
# |    value_loss         | 5.47        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 413         |
# |    iterations         | 7200        |
# |    time_elapsed       | 87          |
# |    total_timesteps    | 36000       |
# | train/                |             |
# |    entropy_loss       | -42.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7199        |
# |    policy_loss        | 163         |
# |    reward             | -0.22246587 |
# |    std                | 1.06        |
# |    value_loss         | 17.2        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 7300      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | -104      |
# |    reward             | 1.2799516 |
# |    std                | 1.06      |
# |    value_loss         | 6.07      |
# -------------------------------------
# day: 334, episode: 110
# begin_total_asset: 1000000.00
# end_total_asset: 1352607.17
# total_reward: 352607.17
# total_cost: 4728.94
# total_trades: 5439
# Sharpe: 1.507
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 7400      |
# |    time_elapsed       | 89        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | 0         |
# ...
# |    policy_loss        | -36.7     |
# |    reward             | 1.6787865 |
# |    std                | 1.06      |
# |    value_loss         | 1.29      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 413       |
# |    iterations         | 7700      |
# |    time_elapsed       | 93        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -42.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -57.5     |
# |    reward             | 3.2862937 |
# |    std                | 1.06      |
# |    value_loss         | 2.39      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 413        |
# |    iterations         | 7800       |
# |    time_elapsed       | 94         |
# |    total_timesteps    | 39000      |
# | train/                |            |
# |    entropy_loss       | -43        |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7799       |
# |    policy_loss        | -24.3      |
# |    reward             | -0.6398732 |
# |    std                | 1.07       |
# |    value_loss         | 0.58       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 413         |
# |    iterations         | 7900        |
# |    time_elapsed       | 95          |
# |    total_timesteps    | 39500       |
# | train/                |             |
# |    entropy_loss       | -43         |
# |    explained_variance | 0.271       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7899        |
# |    policy_loss        | -85.4       |
# |    reward             | -0.59767216 |
# |    std                | 1.07        |
# |    value_loss         | 5.11        |
# ---------------------------------------
# day: 334, episode: 120
# begin_total_asset: 1000000.00
# end_total_asset: 1459256.88
# total_reward: 459256.88
# total_cost: 4842.94
# total_trades: 5659
# Sharpe: 1.991
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 414         |
# |    iterations         | 8000        |
# |    time_elapsed       | 96          |
# |    total_timesteps    | 40000       |
# | train/                |             |
# |    entropy_loss       | -43         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7999        |
# |    policy_loss        | 121         |
# |    reward             | -0.42366436 |
# |    std                | 1.07        |
# |    value_loss         | 7.97        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 414         |
# |    iterations         | 8100        |
# |    time_elapsed       | 97          |
# |    total_timesteps    | 40500       |
# | train/                |             |
# |    entropy_loss       | -43         |
# |    explained_variance | -2.38e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8099        |
# |    policy_loss        | -41.7       |
# |    reward             | -0.04830538 |
# |    std                | 1.07        |
# |    value_loss         | 1.24        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 414       |
# |    iterations         | 8200      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -43       |
# |    explained_variance | 1.37e-06  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8199      |
# |    policy_loss        | -3.34     |
# |    reward             | 2.9225352 |
# |    std                | 1.07      |
# |    value_loss         | 0.222     |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 414         |
# |    iterations         | 8300        |
# |    time_elapsed       | 100         |
# |    total_timesteps    | 41500       |
# | train/                |             |
# |    entropy_loss       | -43         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8299        |
# |    policy_loss        | 16.6        |
# |    reward             | -0.04375077 |
# |    std                | 1.07        |
# |    value_loss         | 0.423       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 414         |
# |    iterations         | 8400        |
# |    time_elapsed       | 101         |
# |    total_timesteps    | 42000       |
# | train/                |             |
# |    entropy_loss       | -43.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8399        |
# |    policy_loss        | -13.4       |
# |    reward             | -0.18600781 |
# |    std                | 1.07        |
# |    value_loss         | 0.338       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 414        |
# |    iterations         | 8500       |
# |    time_elapsed       | 102        |
# |    total_timesteps    | 42500      |
# | train/                |            |
# |    entropy_loss       | -43.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8499       |
# |    policy_loss        | -42.7      |
# |    reward             | 0.16362652 |
# |    std                | 1.07       |
# |    value_loss         | 1.13       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 413        |
# |    iterations         | 8600       |
# |    time_elapsed       | 103        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -43.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | -112       |
# |    reward             | 0.70850044 |
# |    std                | 1.08       |
# |    value_loss         | 7.67       |
# --------------------------------------
# day: 334, episode: 130
# begin_total_asset: 1000000.00
# end_total_asset: 1476651.90
# total_reward: 476651.90
# total_cost: 4871.98
# total_trades: 5411
# Sharpe: 2.103
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 413        |
# |    iterations         | 8700       |
# |    time_elapsed       | 105        |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -43.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8699       |
# |    policy_loss        | 47.9       |
# |    reward             | -1.3468294 |
# |    std                | 1.08       |
# |    value_loss         | 1.66       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 413        |
# |    iterations         | 8800       |
# |    time_elapsed       | 106        |
# |    total_timesteps    | 44000      |
# | train/                |            |
# |    entropy_loss       | -43.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8799       |
# |    policy_loss        | 48.2       |
# |    reward             | -1.0851794 |
# |    std                | 1.08       |
# |    value_loss         | 1.63       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 413        |
# |    iterations         | 8900       |
# |    time_elapsed       | 107        |
# |    total_timesteps    | 44500      |
# | train/                |            |
# |    entropy_loss       | -43.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8899       |
# |    policy_loss        | -8.57      |
# |    reward             | 0.56965643 |
# |    std                | 1.08       |
# |    value_loss         | 0.223      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 413        |
# |    iterations         | 9000       |
# |    time_elapsed       | 108        |
# |    total_timesteps    | 45000      |
# | train/                |            |
# |    entropy_loss       | -43.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8999       |
# |    policy_loss        | -49        |
# |    reward             | 0.15777703 |
# |    std                | 1.08       |
# |    value_loss         | 2.42       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 412         |
# |    iterations         | 9100        |
# |    time_elapsed       | 110         |
# |    total_timesteps    | 45500       |
# | train/                |             |
# |    entropy_loss       | -43.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9099        |
# |    policy_loss        | -29         |
# |    reward             | -0.67636216 |
# |    std                | 1.08        |
# |    value_loss         | 0.436       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 412        |
# |    iterations         | 9200       |
# |    time_elapsed       | 111        |
# |    total_timesteps    | 46000      |
# | train/                |            |
# |    entropy_loss       | -43.4      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9199       |
# |    policy_loss        | -78.9      |
# |    reward             | -1.5280668 |
# |    std                | 1.08       |
# |    value_loss         | 4.21       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 412        |
# |    iterations         | 9300       |
# |    time_elapsed       | 112        |
# |    total_timesteps    | 46500      |
# | train/                |            |
# |    entropy_loss       | -43.4      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9299       |
# |    policy_loss        | 42.2       |
# |    reward             | 0.25844845 |
# |    std                | 1.08       |
# |    value_loss         | 5.97       |
# --------------------------------------
# day: 334, episode: 140
# begin_total_asset: 1000000.00
# end_total_asset: 1557811.80
# total_reward: 557811.80
# total_cost: 4021.93
# total_trades: 5343
# Sharpe: 2.109
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 411        |
# |    iterations         | 9400       |
# |    time_elapsed       | 114        |
# |    total_timesteps    | 47000      |
# | train/                |            |
# |    entropy_loss       | -43.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9399       |
# |    policy_loss        | 70.1       |
# |    reward             | -1.2424026 |
# |    std                | 1.09       |
# |    value_loss         | 4.91       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 411       |
# |    iterations         | 9500      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -43.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9499      |
# |    policy_loss        | -16.7     |
# |    reward             | 1.8449836 |
# |    std                | 1.09      |
# |    value_loss         | 1.07      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 411       |
# |    iterations         | 9600      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -43.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9599      |
# |    policy_loss        | 181       |
# |    reward             | 1.6113883 |
# |    std                | 1.09      |
# |    value_loss         | 31.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 411        |
# |    iterations         | 9700       |
# |    time_elapsed       | 117        |
# |    total_timesteps    | 48500      |
# | train/                |            |
# |    entropy_loss       | -43.6      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9699       |
# |    policy_loss        | 8.05       |
# |    reward             | -0.3014867 |
# |    std                | 1.09       |
# |    value_loss         | 0.532      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 411         |
# |    iterations         | 9800        |
# |    time_elapsed       | 119         |
# |    total_timesteps    | 49000       |
# | train/                |             |
# |    entropy_loss       | -43.6       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9799        |
# |    policy_loss        | -175        |
# |    reward             | -0.29049975 |
# |    std                | 1.09        |
# |    value_loss         | 25.1        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 411        |
# |    iterations         | 9900       |
# |    time_elapsed       | 120        |
# |    total_timesteps    | 49500      |
# | train/                |            |
# |    entropy_loss       | -43.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9899       |
# |    policy_loss        | -8.34      |
# |    reward             | 0.03218426 |
# |    std                | 1.09       |
# |    value_loss         | 1.15       |
# --------------------------------------
# day: 334, episode: 150
# begin_total_asset: 1000000.00
# end_total_asset: 1475063.04
# total_reward: 475063.04
# total_cost: 3730.83
# total_trades: 5395
# Sharpe: 2.068
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 411       |
# |    iterations         | 10000     |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -43.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9999      |
# |    policy_loss        | 2.94      |
# |    reward             | -0.907002 |
# |    std                | 1.1       |
# |    value_loss         | 0.415     |
# -------------------------------------

# %%
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=200000) if if_using_ppo else None

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=70000) if if_using_sac else None

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## Save the trained agent
# Trained agents should have already been saved in the "trained_models" drectory after you run the code blocks above.
#
# For Colab users, the zip files should be at "./trained_models" or "/content/trained_models".
#
# For users running on your local environment, the zip files should be at "./trained_models".
